# %%
# %pip install scipy
# Out:
# ...
#
# ...
#      ---------------------------------------- 42.2/42.2 MB 1.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
磁感应强度 = [30.2, 27.1, 24.1, 21.1, 18.1, 15.1, 12.1, 9.0, 6.0, 3.0, 0.0,
         -3.1, -6.0, -9.1, -12.0, -15.1, -18.1, -21.2, -24.2, -27.2, -30.2,
         -27.2, -24.2, -21.1, -18.1, -15.1, -12.0, -9.0, -6.0, -3.0, 0.0,
         3.0, 6.1, 9.1, 12.1, 15.1, 18.1, 21.2, 24.1, 27.1, 30.2]
磁阻电流 = [2065.0, 2068.3, 2076.8, 2097.5, 2129.9, 2168.0, 2211.2, 2256.1, 2300.2, 2340.6, 2381.0, 2351.6, 2310.8, 2266.3, 2221.0, 2170.4, 2131.1, 2096.4, 2076.8, 2068.3,
        2066.1, 2067.2, 2074.7, 2092.1, 2122.0, 2159.8, 2200.2, 2244.7, 2291.0, 2333.7, 2371.1, 2359.9, 2320.2, 2275.3, 2229.7, 2184.6, 2140.2, 2101.9, 2080.1, 2069.3, 2066.1]

# %%
import matplotlib.pyplot as plt

# Set up the plot
fig, ax = plt.subplots()

# ax.plot(磁感应强度, 磁阻电流, color='#DDDDDD')

# Add dots to the plot
ax.scatter(磁感应强度, 磁阻电流, s=1, color='#555', marker='x')

# Set the color of the x-axis and y-axis
ax.tick_params(axis='both', colors='#88888822')
ax.spines['bottom'].set_color('#aaaaaa66')
ax.spines['left'].set_color('#aaaaaa66')
ax.spines['top'].set_color('#ffffff00')
ax.spines['right'].set_color('#ffffff00')
# Set the plot title and axis labels
# ax.set_title("磁阻电流 vs. 磁感应强度")
# ax.set_xlabel("磁感应强度")
# ax.set_ylabel("磁阻电流")

# Show the plot
plt.savefig('plot2.svg', format='svg')
plt.show()
